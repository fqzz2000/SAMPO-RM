# %%
from argparse import ArgumentParser
import matplotlib.pyplot as plt
from envs.ramp_merge import Vehicle
import gym
import torch
from yaml import load
from cpo import CPO
from memory import Memory
from models import build_diag_gauss_policy, build_mlp
from simulators import SinglePathSimulator
from torch_utils.torch_utils import get_device
import torch.nn as nn
from torch.nn import Linear, LogSoftmax, Module, Parameter, Sequential, Tanh
from torch.distributions.normal import Normal
from torch.distributions import Independent
import seaborn as sns
import numpy as np

# %%
state_dim = 5
action_dim = 1

n_episodes = 20
env_name = 'ramp_merge'
model_name = 'cpo'
n_trajectories = 20
trajectory_len = 1000
policy_dims = [120]
vf_dims = [80]
cf_dims = [80]
max_constraint_val = 0.1


deltat=0.01
speed_limit = 35
feasible_set = (8,-15)
# bias_red_cost = config['bias_red_cost']
device = get_device()

# %%
class DiagGaussianLayer(Module):
    '''
    Implements a layer that outputs a Gaussian distribution with a diagonal
    covariance matrix

    Attributes
    ----------
    log_std : torch.FloatTensor
        the log square root of the diagonal elements of the covariance matrix

    Methods
    -------
    __call__(mean)
        takes as input a mean vector and outputs a Gaussian distribution with
        diagonal covariance matrix defined by log_std

        '''

    def __init__(self, output_dim=None, log_std=None):
        Module.__init__(self)

        self.log_std = log_std

        if log_std is None:
            self.log_std = Parameter(torch.zeros(output_dim), requires_grad=True)

    def __call__(self, mean):
        std = torch.exp(self.log_std)
        normal_dist = Independent(Normal(loc=mean, scale=std), 1)

        return normal_dist
class Net(nn.Module):
    def __init__(self, input_dim, hidden_dims, output_dim, speed_limit=speed_limit, feasible_set=feasible_set,deltat=deltat):
        super().__init__()
        layer_sizes = [input_dim] + hidden_dims + [output_dim]
        layers = []
        for i in range(len(layer_sizes) - 1):
            layers.append(Linear(layer_sizes[i], layer_sizes[i + 1], bias=True))

            if i != len(layer_sizes) - 2:
                layers.append(Tanh())
        layers.append(Tanh())
        self.layer = Sequential(*layers)
        self.gaussian = DiagGaussianLayer(output_dim=output_dim)
        self.speed_limit = speed_limit
        self.u_max, self.u_min = feasible_set
        self.deltat = deltat

    def forward(self, x):
        u_max,u_min = self.compute_action_space(x)
        x = self.layer(x)
        x = ((u_max-u_min)/2)*x + (u_max + u_min)/2
#         x = 8*x
        try:
            x = self.gaussian(x)
        except:
            print(x)

        return x
    
    def compute_action_space(self,x):

        v = x[:,-2]
        upper = (self.speed_limit - v)/self.deltat
        upper[upper > self.u_max] = self.u_max 
        upper[upper < self.u_min] = self.u_min
        u_max = upper
        lower = (0 - v)/self.deltat
        lower[lower < self.u_min] = self.u_min
        lower[lower > self.u_max] = self.u_max
        u_min = lower
        return u_max.reshape(-1,1),u_min.reshape(-1,1)

# %%
def build_policy(input_dim, hidden_dims, output_dim):
    layer_sizes = [input_dim] + hidden_dims + [output_dim]
    layers = []
    for i in range(len(layer_sizes) - 1):
        layers.append(Linear(layer_sizes[i], layer_sizes[i + 1], bias=True))

        if i != len(layer_sizes) - 2:
            layers.append(Tanh())
    layers.append(Tanh())
    return Sequential(*layers)

# %%
# policy = build_diag_gauss_policy(state_dim, policy_dims, action_dim)

policy = Net(state_dim, policy_dims, action_dim)
value_fun = build_mlp(state_dim + 1, vf_dims, 1)
cost_fun = build_mlp(state_dim + 1, cf_dims, 1)

policy.to(device)
value_fun.to(device)
cost_fun.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=6, out_features=80, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=80, out_features=1, bias=True)
# )

# %%
policy.load_state_dict(torch.load('infeasible_initial.pth'))
# Out:
# <All keys matched successfully>

# %%
x1,y1,v1,x2,y2,v2 = (0,-90,20,12.5,-90,20)
ego =Vehicle(x1,y1,v1)
host = Vehicle(x2,y2,v2)

# %%
simulator = SinglePathSimulator(env_name, policy, n_trajectories, trajectory_len, ego=ego, host=host, deltat=0.01,uncertainty=0.01,expected_a=5,safethreshold=8)
cpo = CPO(policy, value_fun, cost_fun, simulator, model_name=model_name,
           max_constraint_val=max_constraint_val)

print(f'Training policy {model_name} on {env_name} environment...\n')
# Out:
# Training policy cpo on ramp_merge environment...

# %%
actions = cpo.train(800)
# Out:
# D:\RISS\Code\cpo-pytorch-master\cpo-pytorch-master\simulators.py:68: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   policy_input = torch.stack([torch.tensor(trajectory.observations[-1]).to(self.device)
# Step Len.: 1.0
#
# [Episode]: 601 | [Avg. Reward]: -30709.693359375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:09:36
# Step Len.: 0.81
#
# [Episode]: 602 | [Avg. Reward]: -30398.021484375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:09:40
# Step Len.: 1.0
#
# [Episode]: 603 | [Avg. Reward]: -30787.73046875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:09:43
# Step Len.: 0.9
#
# [Episode]: 604 | [Avg. Reward]: -30059.66796875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:09:47
# Step Len.: 1.0
#
# [Episode]: 605 | [Avg. Reward]: -30251.78125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:09:52
# Step Len.: 1.0
#
# [Episode]: 606 | [Avg. Reward]: -32295.90234375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:09:55
# Step Len.: 0.43046721000000016
#
# [Episode]: 607 | [Avg. Reward]: -31362.822265625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:09:59
# Step Len.: 0.5904900000000002
#
# [Episode]: 608 | [Avg. Reward]: -31477.150390625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:02
# Step Len.: 0.9
#
# [Episode]: 609 | [Avg. Reward]: -32916.01953125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:06
# Step Len.: 0.81
#
# [Episode]: 610 | [Avg. Reward]: -32229.119140625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:09
# Step Len.: 1.0
#
# [Episode]: 611 | [Avg. Reward]: -33570.47265625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:13
# Step Len.: 0.9
#
# [Episode]: 612 | [Avg. Reward]: -30909.09375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:16
# Step Len.: 0.81
#
# [Episode]: 613 | [Avg. Reward]: -30029.099609375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:21
# Step Len.: 1.0
#
# [Episode]: 614 | [Avg. Reward]: -30532.36328125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:24
# Step Len.: 0.47829690000000014
#
# [Episode]: 615 | [Avg. Reward]: -29768.681640625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:28
# Step Len.: 0.9
#
# [Episode]: 616 | [Avg. Reward]: -30109.462890625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:31
# Step Len.: 1.0
#
# [Episode]: 617 | [Avg. Reward]: -29399.962890625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:35
# Step Len.: tensor(0.)
#
# [Episode]: 618 | [Avg. Reward]: -29989.84375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:38
# Step Len.: 0.47829690000000014
#
# [Episode]: 619 | [Avg. Reward]: -29305.537109375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:42
# Step Len.: 0.7290000000000001
#
# [Episode]: 620 | [Avg. Reward]: -29135.13671875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:45
# Step Len.: 0.38742048900000015
#
# [Episode]: 621 | [Avg. Reward]: -29386.26171875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:49
# Step Len.: 1.0
#
# [Episode]: 622 | [Avg. Reward]: -29534.34765625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:53
# Step Len.: 1.0
#
# [Episode]: 623 | [Avg. Reward]: -29367.72265625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:10:57
# Step Len.: 0.81
#
# [Episode]: 624 | [Avg. Reward]: -29293.869140625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:01
# Step Len.: 0.9
#
# [Episode]: 625 | [Avg. Reward]: -29606.759765625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:04
# Step Len.: 1.0
#
# [Episode]: 626 | [Avg. Reward]: -29823.88671875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:08
# Step Len.: 0.81
#
# [Episode]: 627 | [Avg. Reward]: -29636.45703125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:11
# Step Len.: 1.0
#
# [Episode]: 628 | [Avg. Reward]: -30043.48828125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:15
# Step Len.: 0.9
#
# [Episode]: 629 | [Avg. Reward]: -29857.61328125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:19
# Step Len.: 1.0
#
# [Episode]: 630 | [Avg. Reward]: -29709.41015625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:22
# Step Len.: 0.9
#
# [Episode]: 631 | [Avg. Reward]: -29871.88671875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:27
# Step Len.: 0.9
#
# [Episode]: 632 | [Avg. Reward]: -29587.40234375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:31
# Step Len.: 0.5904900000000002
#
# [Episode]: 633 | [Avg. Reward]: -29445.818359375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:34
# Step Len.: 0.81
#
# [Episode]: 634 | [Avg. Reward]: -29455.19921875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:37
# Step Len.: 0.6561000000000001
#
# [Episode]: 635 | [Avg. Reward]: -29395.181640625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:41
# Step Len.: 0.5904900000000002
#
# [Episode]: 636 | [Avg. Reward]: -29358.3125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:44
# Step Len.: 1.0
#
# [Episode]: 637 | [Avg. Reward]: -29493.474609375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:48
# Step Len.: 0.9
#
# [Episode]: 638 | [Avg. Reward]: -29234.921875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:51
# Step Len.: 1.0
#
# [Episode]: 639 | [Avg. Reward]: -29022.568359375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:11:56
# Step Len.: 0.9
#
# [Episode]: 640 | [Avg. Reward]: -29178.21875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:00
# Step Len.: 0.9
#
# [Episode]: 641 | [Avg. Reward]: -28832.92578125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:03
# Step Len.: 1.0
#
# [Episode]: 642 | [Avg. Reward]: -28693.462890625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:07
# Step Len.: 1.0
#
# [Episode]: 643 | [Avg. Reward]: -28641.84375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:11
# Step Len.: 1.0
#
# [Episode]: 644 | [Avg. Reward]: -28373.671875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:14
# Step Len.: tensor(0.)
#
# [Episode]: 645 | [Avg. Reward]: -28461.87890625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:18
# Step Len.: 0.9
#
# [Episode]: 646 | [Avg. Reward]: -28435.556640625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:22
# Step Len.: 0.9
#
# [Episode]: 647 | [Avg. Reward]: -28380.515625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:25
# Step Len.: 1.0
#
# [Episode]: 648 | [Avg. Reward]: -28234.505859375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:30
# Step Len.: 0.9
#
# [Episode]: 649 | [Avg. Reward]: -28170.365234375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:33
# Step Len.: 0.9
#
# [Episode]: 650 | [Avg. Reward]: -28206.666015625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:37
# Step Len.: 0.9
#
# [Episode]: 651 | [Avg. Reward]: -28179.103515625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:41
# Step Len.: 0.9
#
# [Episode]: 652 | [Avg. Reward]: -27918.958984375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:44
# Step Len.: 0.9
#
# [Episode]: 653 | [Avg. Reward]: -27870.349609375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:48
# Step Len.: 1.0
#
# [Episode]: 654 | [Avg. Reward]: -27833.380859375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:51
# Step Len.: 0.5314410000000002
#
# [Episode]: 655 | [Avg. Reward]: -27789.791015625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:55
# Step Len.: 0.47829690000000014
#
# [Episode]: 656 | [Avg. Reward]: -27756.875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:12:58
# Step Len.: 0.7290000000000001
#
# [Episode]: 657 | [Avg. Reward]: -27686.09765625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:03
# Step Len.: 0.6561000000000001
#
# [Episode]: 658 | [Avg. Reward]: -27713.552734375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:07
# Step Len.: 0.9
#
# [Episode]: 659 | [Avg. Reward]: -27687.046875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:10
# Step Len.: 0.9
#
# [Episode]: 660 | [Avg. Reward]: -27755.48828125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:13
# Step Len.: 1.0
#
# [Episode]: 661 | [Avg. Reward]: -27597.41015625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:17
# Step Len.: 1.0
#
# [Episode]: 662 | [Avg. Reward]: -27689.244140625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:20
# Step Len.: 0.5904900000000002
#
# [Episode]: 663 | [Avg. Reward]: -27822.85546875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:24
# Step Len.: 0.5314410000000002
#
# [Episode]: 664 | [Avg. Reward]: -27677.55078125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:27
# Step Len.: 0.9
#
# [Episode]: 665 | [Avg. Reward]: -27739.005859375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:31
# Step Len.: 0.9
#
# [Episode]: 666 | [Avg. Reward]: -27621.619140625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:34
# Step Len.: 0.5314410000000002
#
# [Episode]: 667 | [Avg. Reward]: -27573.58984375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:39
# Step Len.: 0.7290000000000001
#
# [Episode]: 668 | [Avg. Reward]: -27570.181640625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:43
# Step Len.: 0.9
#
# [Episode]: 669 | [Avg. Reward]: -27600.458984375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:46
# Step Len.: 1.0
#
# [Episode]: 670 | [Avg. Reward]: -27601.88671875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:50
# Step Len.: 0.9
#
# [Episode]: 671 | [Avg. Reward]: -27728.00390625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:53
# Step Len.: 1.0
#
# [Episode]: 672 | [Avg. Reward]: -27793.353515625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:13:56
# Step Len.: 0.9
#
# [Episode]: 673 | [Avg. Reward]: -27668.984375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:00
# Step Len.: 0.9
#
# [Episode]: 674 | [Avg. Reward]: -27767.912109375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:03
# Step Len.: 1.0
#
# [Episode]: 675 | [Avg. Reward]: -27527.87890625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:07
# Step Len.: 0.9
#
# [Episode]: 676 | [Avg. Reward]: -27442.474609375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:11
# Step Len.: 0.9
#
# [Episode]: 677 | [Avg. Reward]: -27636.947265625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:15
# Step Len.: 0.9
#
# [Episode]: 678 | [Avg. Reward]: -27921.775390625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:18
# Step Len.: 0.9
#
# [Episode]: 679 | [Avg. Reward]: -27400.021484375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:22
# Step Len.: 1.0
#
# [Episode]: 680 | [Avg. Reward]: -27347.28515625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:25
# Step Len.: 0.9
#
# [Episode]: 681 | [Avg. Reward]: -27227.80859375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:29
# Step Len.: 1.0
#
# [Episode]: 682 | [Avg. Reward]: -27280.318359375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:32
# Step Len.: 0.9
#
# [Episode]: 683 | [Avg. Reward]: -27276.45703125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:35
# Step Len.: 0.9
#
# [Episode]: 684 | [Avg. Reward]: -27292.734375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:39
# Step Len.: 0.9
#
# [Episode]: 685 | [Avg. Reward]: -27266.41015625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:44
# Step Len.: 0.9
#
# [Episode]: 686 | [Avg. Reward]: -27315.203125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:47
# Step Len.: 0.9
#
# [Episode]: 687 | [Avg. Reward]: -27127.818359375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:51
# Step Len.: 1.0
#
# [Episode]: 688 | [Avg. Reward]: -27008.275390625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:54
# Step Len.: 0.9
#
# [Episode]: 689 | [Avg. Reward]: -26954.078125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:14:58
# Step Len.: 0.9
#
# [Episode]: 690 | [Avg. Reward]: -26799.23828125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:01
# Step Len.: 0.9
#
# [Episode]: 691 | [Avg. Reward]: -26885.91015625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:04
# Step Len.: 0.9
#
# [Episode]: 692 | [Avg. Reward]: -26850.130859375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:08
# Step Len.: 1.0
#
# [Episode]: 693 | [Avg. Reward]: -26757.130859375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:11
# Step Len.: 1.0
#
# [Episode]: 694 | [Avg. Reward]: -26803.005859375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:15
# Step Len.: 0.6561000000000001
#
# [Episode]: 695 | [Avg. Reward]: -26662.56640625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:20
# Step Len.: 0.81
#
# [Episode]: 696 | [Avg. Reward]: -26589.650390625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:23
# Step Len.: 1.0
#
# [Episode]: 697 | [Avg. Reward]: -26590.26953125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:27
# Step Len.: 0.7290000000000001
#
# [Episode]: 698 | [Avg. Reward]: -26466.375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:30
# Step Len.: 0.9
#
# [Episode]: 699 | [Avg. Reward]: -26418.974609375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:34
# Step Len.: 0.47829690000000014
#
# [Episode]: 700 | [Avg. Reward]: -26460.703125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:37
# Step Len.: 0.9
#
# [Episode]: 701 | [Avg. Reward]: -26451.19921875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:41
# Step Len.: 0.9
#
# [Episode]: 702 | [Avg. Reward]: -26504.0625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:44
# Step Len.: 1.0
#
# [Episode]: 703 | [Avg. Reward]: -26426.8125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:47
# Step Len.: 1.0
#
# [Episode]: 704 | [Avg. Reward]: -26489.853515625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:52
# Step Len.: 0.5904900000000002
#
# [Episode]: 705 | [Avg. Reward]: -26533.60546875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:56
# Step Len.: 0.9
#
# [Episode]: 706 | [Avg. Reward]: -26529.162109375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:15:59
# Step Len.: 0.5314410000000002
#
# [Episode]: 707 | [Avg. Reward]: -26484.04296875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:02
# Step Len.: 1.0
#
# [Episode]: 708 | [Avg. Reward]: -26530.66796875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:06
# Step Len.: 1.0
#
# [Episode]: 709 | [Avg. Reward]: -26750.37109375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:09
# Step Len.: 0.43046721000000016
#
# [Episode]: 710 | [Avg. Reward]: -26624.01953125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:13
# Step Len.: 0.9
#
# [Episode]: 711 | [Avg. Reward]: -26611.509765625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:16
# Step Len.: 1.0
#
# [Episode]: 712 | [Avg. Reward]: -26546.05859375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:20
# Step Len.: 0.9
#
# [Episode]: 713 | [Avg. Reward]: -26521.634765625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:23
# Step Len.: 0.47829690000000014
#
# [Episode]: 714 | [Avg. Reward]: -26639.443359375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:28
# Step Len.: 0.9
#
# [Episode]: 715 | [Avg. Reward]: -26629.255859375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:31
# Step Len.: 1.0
#
# [Episode]: 716 | [Avg. Reward]: -26576.943359375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:35
# Step Len.: 0.9
#
# [Episode]: 717 | [Avg. Reward]: -26572.177734375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:38
# Step Len.: 0.9
#
# [Episode]: 718 | [Avg. Reward]: -26633.943359375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:42
# Step Len.: 0.9
#
# [Episode]: 719 | [Avg. Reward]: -26683.822265625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:45
# Step Len.: 0.5314410000000002
#
# [Episode]: 720 | [Avg. Reward]: -26605.275390625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:48
# Step Len.: 0.9
#
# [Episode]: 721 | [Avg. Reward]: -26651.07421875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:52
# Step Len.: 0.9
#
# [Episode]: 722 | [Avg. Reward]: -26527.599609375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:55
# Step Len.: 0.9
#
# [Episode]: 723 | [Avg. Reward]: -26614.92578125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:16:59
# Step Len.: 0.6561000000000001
#
# [Episode]: 724 | [Avg. Reward]: -26698.140625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:03
# Step Len.: 1.0
#
# [Episode]: 725 | [Avg. Reward]: -26598.328125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:07
# Step Len.: 1.0
#
# [Episode]: 726 | [Avg. Reward]: -26776.958984375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:10
# Step Len.: 0.9
#
# [Episode]: 727 | [Avg. Reward]: -26594.70703125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:14
# Step Len.: 0.5314410000000002
#
# [Episode]: 728 | [Avg. Reward]: -26579.09765625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:17
# Step Len.: 0.9
#
# [Episode]: 729 | [Avg. Reward]: -26605.921875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:20
# Step Len.: 0.9
#
# [Episode]: 730 | [Avg. Reward]: -26637.984375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:24
# Step Len.: 0.9
#
# [Episode]: 731 | [Avg. Reward]: -26718.59765625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:27
# Step Len.: 0.5904900000000002
#
# [Episode]: 732 | [Avg. Reward]: -26597.744140625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:31
# Step Len.: 0.9
#
# [Episode]: 733 | [Avg. Reward]: -26684.693359375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:36
# Step Len.: 0.9
#
# [Episode]: 734 | [Avg. Reward]: -26584.70703125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:39
# Step Len.: 0.9
#
# [Episode]: 735 | [Avg. Reward]: -26523.671875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:42
# Step Len.: 1.0
#
# [Episode]: 736 | [Avg. Reward]: -26479.3125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:46
# Step Len.: 0.6561000000000001
#
# [Episode]: 737 | [Avg. Reward]: -26432.15234375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:49
# Step Len.: 1.0
#
# [Episode]: 738 | [Avg. Reward]: -26524.958984375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:53
# Step Len.: 0.38742048900000015
#
# [Episode]: 739 | [Avg. Reward]: -26508.12890625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:17:56
# Step Len.: 0.81
#
# [Episode]: 740 | [Avg. Reward]: -26462.04296875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:00
# Step Len.: 0.9
#
# [Episode]: 741 | [Avg. Reward]: -26508.62109375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:03
# Step Len.: 1.0
#
# [Episode]: 742 | [Avg. Reward]: -26574.166015625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:06
# Step Len.: 0.81
#
# [Episode]: 743 | [Avg. Reward]: -26492.66015625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:11
# Step Len.: 0.9
#
# [Episode]: 744 | [Avg. Reward]: -26515.974609375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:15
# Step Len.: 0.9
#
# [Episode]: 745 | [Avg. Reward]: -26595.44140625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:18
# Step Len.: 0.47829690000000014
#
# [Episode]: 746 | [Avg. Reward]: -26775.42578125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:21
# Step Len.: 1.0
#
# [Episode]: 747 | [Avg. Reward]: -26775.724609375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:25
# Step Len.: 0.81
#
# [Episode]: 748 | [Avg. Reward]: -26921.1875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:28
# Step Len.: 1.0
#
# [Episode]: 749 | [Avg. Reward]: -27055.6875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:32
# Step Len.: 0.7290000000000001
#
# [Episode]: 750 | [Avg. Reward]: -27174.912109375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:35
# Step Len.: 1.0
#
# [Episode]: 751 | [Avg. Reward]: -27113.953125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:38
# Step Len.: 0.9
#
# [Episode]: 752 | [Avg. Reward]: -26929.76953125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:42
# Step Len.: 0.9
#
# [Episode]: 753 | [Avg. Reward]: -26853.037109375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:45
# Step Len.: 1.0
#
# [Episode]: 754 | [Avg. Reward]: -26829.60546875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:50
# Step Len.: 0.38742048900000015
#
# [Episode]: 755 | [Avg. Reward]: -26899.34375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:54
# Step Len.: 1.0
#
# [Episode]: 756 | [Avg. Reward]: -26924.46484375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:18:57
# Step Len.: 0.47829690000000014
#
# [Episode]: 757 | [Avg. Reward]: -26963.978515625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:01
# Step Len.: 0.9
#
# [Episode]: 758 | [Avg. Reward]: -26941.98046875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:04
# Step Len.: 0.43046721000000016
#
# [Episode]: 759 | [Avg. Reward]: -26901.453125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:07
# Step Len.: 1.0
#
# [Episode]: 760 | [Avg. Reward]: -26905.59765625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:11
# Step Len.: 1.0
#
# [Episode]: 761 | [Avg. Reward]: -26844.22265625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:14
# Step Len.: 0.6561000000000001
#
# [Episode]: 762 | [Avg. Reward]: -26761.947265625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:18
# Step Len.: 0.9
#
# [Episode]: 763 | [Avg. Reward]: -26860.203125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:21
# Step Len.: 0.38742048900000015
#
# [Episode]: 764 | [Avg. Reward]: -26983.8125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:26
# Step Len.: 0.9
#
# [Episode]: 765 | [Avg. Reward]: -26958.177734375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:29
# Step Len.: 0.9
#
# [Episode]: 766 | [Avg. Reward]: -26972.484375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:33
# Step Len.: 0.9
#
# [Episode]: 767 | [Avg. Reward]: -26920.787109375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:36
# Step Len.: 1.0
#
# [Episode]: 768 | [Avg. Reward]: -26824.55859375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:40
# Step Len.: 0.9
#
# [Episode]: 769 | [Avg. Reward]: -26854.240234375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:43
# Step Len.: 1.0
#
# [Episode]: 770 | [Avg. Reward]: -26802.291015625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:46
# Step Len.: 0.47829690000000014
#
# [Episode]: 771 | [Avg. Reward]: -26793.41796875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:50
# Step Len.: 1.0
#
# [Episode]: 772 | [Avg. Reward]: -26712.744140625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:53
# Step Len.: 0.43046721000000016
#
# [Episode]: 773 | [Avg. Reward]: -26754.412109375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:19:57
# Step Len.: 1.0
#
# [Episode]: 774 | [Avg. Reward]: -26793.974609375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:02
# Step Len.: 0.9
#
# [Episode]: 775 | [Avg. Reward]: -26716.58203125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:05
# Step Len.: 0.9
#
# [Episode]: 776 | [Avg. Reward]: -26690.103515625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:08
# Step Len.: 0.9
#
# [Episode]: 777 | [Avg. Reward]: -26693.203125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:12
# Step Len.: 1.0
#
# [Episode]: 778 | [Avg. Reward]: -26752.349609375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:15
# Step Len.: 0.5904900000000002
#
# [Episode]: 779 | [Avg. Reward]: -26796.44140625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:19
# Step Len.: 1.0
#
# [Episode]: 780 | [Avg. Reward]: -26733.212890625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:22
# Step Len.: 0.9
#
# [Episode]: 781 | [Avg. Reward]: -26663.115234375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:25
# Step Len.: 1.0
#
# [Episode]: 782 | [Avg. Reward]: -26657.578125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:29
# Step Len.: 0.9
#
# [Episode]: 783 | [Avg. Reward]: -26654.09765625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:32
# Step Len.: 0.5904900000000002
#
# [Episode]: 784 | [Avg. Reward]: -26567.037109375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:36
# Step Len.: 0.9
#
# [Episode]: 785 | [Avg. Reward]: -26643.45703125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:41
# Step Len.: 0.9
#
# [Episode]: 786 | [Avg. Reward]: -26682.78125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:44
# Step Len.: 0.9
#
# [Episode]: 787 | [Avg. Reward]: -26662.1875 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:48
# Step Len.: 1.0
#
# [Episode]: 788 | [Avg. Reward]: -26568.93359375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:51
# Step Len.: 0.9
#
# [Episode]: 789 | [Avg. Reward]: -26671.87109375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:54
# Step Len.: 0.9
#
# [Episode]: 790 | [Avg. Reward]: -26577.880859375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:20:58
# Step Len.: 0.9
#
# [Episode]: 791 | [Avg. Reward]: -26565.05078125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:21:01
# Step Len.: 1.0
#
# [Episode]: 792 | [Avg. Reward]: -26572.197265625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:21:05
# Step Len.: 1.0
#
# [Episode]: 793 | [Avg. Reward]: -26555.83203125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:21:08
# Step Len.: 0.9
#
# [Episode]: 794 | [Avg. Reward]: -26537.578125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:21:12
# Step Len.: 1.0
#
# [Episode]: 795 | [Avg. Reward]: -26486.25 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:21:17
# Step Len.: 1.0
#
# [Episode]: 796 | [Avg. Reward]: -26527.45703125 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:21:20
# Step Len.: tensor(0.)
#
# [Episode]: 797 | [Avg. Reward]: -26520.650390625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:21:23
# Step Len.: 0.9
#
# [Episode]: 798 | [Avg. Reward]: -26547.990234375 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:21:27
# Step Len.: 0.7290000000000001
#
# [Episode]: 799 | [Avg. Reward]: -26527.625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:21:30
# Step Len.: 0.38742048900000015
#
# [Episode]: 800 | [Avg. Reward]: -26523.259765625 | [Avg. Cost]: 0.0 | [Elapsed Time]: 1:21:34

# %%
plt.plot(np.asarray([i.numpy()[-2]for i in cpo.simulator.traj[780].observations]))

# %%
import pandas as pd
pd.Series(cpo.violation).to_csv('cpo_violation.csv')
pd.Series(cpo.mean_rewards).to_csv('cpo_mean_reward.csv')

# %%
cpo.policy(torch.tensor([[-90,12.5,-90,0,30]]).to(device)).log_prob(torch.tensor([0]).to(device))
# Out:
# tensor([-18.5225], device='cuda:0', grad_fn=<SumBackward1>)

# %%
plt.figure(figsize=(10,7))
plt.plot(cpo.mean_rewards,label='CPO')
plt.legend()
plt.xlabel('The Number of Epoch',fontsize=15)
plt.ylabel('Average Return',fontsize=15)
plt.grid()

# %%
plt.figure(figsize=(10,7))
plt.plot(cpo.violation,label='CPO')
plt.legend()
plt.xlabel('The Number of Epoch',fontsize=20)
plt.ylabel('Eposide Constraint Violation Distance',fontsize=20)
plt.grid()

# %%
import pandas as pd
pd.Series(cpo.mean_rewards).to_csv('cpo_mean_rewards.csv')

# %%
cpo.simulator.traj[1201].observations
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-1565ad973fe2> in <module>
# ----> 1 cpo.simulator.traj[1201].observations
#
# IndexError: list index out of range

# %%
sns.kdeplot(np.array(cpo.simulator.state_traj[1000].actions).squeeze(),shade = 1)

# %%
def compute_violation(trajectories):
    val = 64-((trajectories[:,:,0] - trajectories[:,:,2])**2 + (trajectories[:,:,1] - 0)**2)
    val[val<0] = 0
    val.sum(0).mean(1)
    return val

# %%
plt.plot(np.array(cpo.violation) + 0.001)

# %%
cpo.violation

# %%
fifty = np.asarray([[j.numpy() for j in i.observations] for i in cpo.simulator.state_traj[:50]])

# %%
val = compute_violation(fifty)

# %%
val[val<0]=0

# %%
val.sum(1).mean(0)

# %%
action_dists = mbpo.policy(torch.tensor([-90,12.5,-90,0,30]).to(device))

# %%
from scipy.integrate import quad

# %%
def f(x):
    return np.array([x]*100)
    
quad(f,-np.inf,np.inf)

# %%
import pandas as pd
vio = pd.read_csv('cpo_mean_rewards.csv')

# %%
plt.plot(vio['CPO'],label = 'CPO')
plt.legend()
plt.xlabel('# of episode',fontsize=15)
plt.ylabel('average reward',fontsize=15)
plt.grid()
